# %%
lista = ["vinicius","Matheus","Ana","Zé","Manoel"]
numeros = [1,2,3,4,5]

# %%
for i in range(5):
  if(i%2==0):
    print(lista[i])
# Out:
# vinicius
# Ana
# Manoel

# %%
for i in range(5):
  if(i%2==0):
    print(numeros[i])
# Out:
# 1
# 3
# 5

# %%
tabela = {"nome": ["vinicius","Matheus","Ana","Zé","Manoel","Tobias"],"idade":[18,19,20,21,22,780]}
tabela
# Out:
# {'nome': ['vinicius', 'Matheus', 'Ana', 'Zé', 'Manoel', 'Tobias'],
#  'idade': [18, 19, 20, 21, 22, 780]}

# %%
import pandas as pd
df=pd.DataFrame(tabela)
df
# Out:
#        nome  idade
# 0  vinicius     18
# 1   Matheus     19
# 2       Ana     20
# 3        Zé     21
# 4    Manoel     22
# 5    Tobias    780

# %%
df['idade'][3]
# Out:
# 21
